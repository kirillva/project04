# %%
# conda activate directml

# %%
# %pip install tqdm pandarallel transformers wordcloud ipywidgets
# Out:
# UsageError: Line magic function `%pip` not found.

# %%
# %conda install -n directml torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu117
# Out:
# UsageError: Line magic function `%conda` not found.

# %%
from PIL import Image
from transformers import AutoFeatureExtractor, ResNetForImageClassification
from tensorflow.keras.preprocessing.image import ImageDataGenerator 


from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications.resnet import ResNet50
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import GlobalAveragePooling2D, Conv2D, Flatten, Dense, AvgPool2D, Dropout
from tensorflow.keras.metrics import MeanAbsoluteError
from keras.applications.resnet50 import preprocess_input
import matplotlib.pyplot as plt
import numpy as np
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-7-57559e31eb4c> in <module>()
#       1
# ----> 2 from PIL import Image
#       3 from transformers import AutoFeatureExtractor, ResNetForImageClassification
#       4 from tensorflow.keras.preprocessing.image import ImageDataGenerator
#       5
#
# ModuleNotFoundError: No module named 'PIL'

# %%
import tensorflow as tf
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-b3c3452a9f10> in <module>()
#       1 import tensorflow as tf
# ----> 2 print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
#
# /home/k-avtonomov/miniconda3/envs/directml/lib/python3.6/site-packages/tensorflow_core/python/util/module_wrapper.py in __getattr__(self, name)
#     191   def __getattr__(self, name):
#     192     try:
# --> 193       attr = getattr(self._tfmw_wrapped_module, name)
#     194     except AttributeError:
#     195       if not self._tfmw_public_apis:
#
# AttributeError: module 'tensorflow._api.v1.config' has no attribute 'list_physical_devices'

# %%
MAX_LENGTH = 150
ORIGINAL_DIR = './original'
image_name = '54501196_a9ac9d66f2.jpg'
# Out:
# Running cells with 'directml' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'conda install -n directml ipykernel --update-deps --force-reinstall'

# %%
# # backbone = ResNet50(input_shape=(224, 224, 3),
# #     weights='imagenet',
# #     include_top=False
# # )

# backbone = ResNet50(weights='imagenet', include_top=False,input_shape=(224, 224, 3),pooling='max')

# model = Sequential()
# model.add(backbone)
# # model.add(GlobalAveragePooling2D())
# model.add(Dense(units=MAX_LENGTH, activation='relu'))

# # optimizer = Adam(lr=0.0005)

# %%
image = Image.open(f'{ORIGINAL_DIR}/images/{image_name}')
plt.imshow(np.array(image))

# %%
model = ResNet50(weights='imagenet', include_top=False,input_shape=(224, 224, 3),pooling='max')

def read_img_file(f):
    img = Image.open(f)
    if img.mode != 'RGB':
        img = img.convert('RGB')
    return img

def resize_img_to_array(img, img_shape):
    img_array = np.array(
        img.resize(
            img_shape, 
            # Image.ANTIALIAS
        )
    )    
    return img_array

def get_features(img):
    img_width, img_height = 224, 224
    np_img = resize_img_to_array(img, img_shape=(img_width, img_height))
    expanded_img_array = np.expand_dims(np_img, axis=0)
    preprocessed_img = preprocess_input(expanded_img_array)
    X_conv = model.predict(preprocessed_img)
    return X_conv
    # image_features=X_conv[0]
    # image_features /=  np.linalg.norm(image_features)
    # return image_features
    
get_features(image)
# Out:
# 2023-08-15 21:08:28.723792: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] could not open file to read NUMA node: /sys/bus/pci/devices/0000:26:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-08-15 21:08:28.723894: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] could not open file to read NUMA node: /sys/bus/pci/devices/0000:26:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-08-15 21:08:28.723922: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] could not open file to read NUMA node: /sys/bus/pci/devices/0000:26:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-08-15 21:08:31.098874: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] could not open file to read NUMA node: /sys/bus/pci/devices/0000:26:00.0/numa_node
# Your kernel may have been built without NUMA support.
# ...
